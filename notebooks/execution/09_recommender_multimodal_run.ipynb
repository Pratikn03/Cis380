# %% [markdown]
# # Execution: Recommender Multimodal
#
# Build multimodal index and validate recommendations.

# %% [markdown]
# ## Inputs
# - scripts/build_recommender_index.py
# - app/api/recommender.py

# %% [markdown]
# ## Outputs
# - Index build status
# - Multimodal results

# %% [markdown]
# ## Steps
# 1. Build multimodal index
# 2. Review metadata
# 3. Call multimodal endpoint

# %%
# TODO: python scripts/build_recommender_index.py
# TODO: curl -X POST http://localhost:8000/api/recommender/multimodal -H 'Content-Type: application/json' -d '{"text":"summer outfit"}'
