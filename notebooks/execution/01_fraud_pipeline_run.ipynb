# %% [markdown]
# # Execution: Fraud Pipeline Run
#
# Run supervised fraud training and a sample inference.

# %% [markdown]
# ## Inputs
# - configs/fraud_baseline.yaml
# - scripts/train_production.py
# - app/api/fraud.py

# %% [markdown]
# ## Outputs
# - Fraud metrics
# - Sample inference response

# %% [markdown]
# ## Steps
# 1. Train model
# 2. Review metrics JSON
# 3. Call fraud endpoint

# %%
# TODO: python scripts/train_production.py --config configs/fraud_baseline.yaml --seed 42
# TODO: curl -X POST http://localhost:8000/api/fraud -H 'Content-Type: application/json' -d '{"amount":123.45}'
