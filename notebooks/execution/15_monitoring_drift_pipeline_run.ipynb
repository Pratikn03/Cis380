# %% [markdown]
# # Execution: Monitoring and Drift
#
# Run drift computation and review monitoring outputs.

# %% [markdown]
# ## Inputs
# - app/monitoring
# - app/api/monitor.py

# %% [markdown]
# ## Outputs
# - Drift report
# - Monitoring summary

# %% [markdown]
# ## Steps
# 1. Call monitor summary
# 2. Call drift endpoint
# 3. Record outputs

# %%
# TODO: curl -s http://localhost:8000/api/monitor/summary
# TODO: curl -s http://localhost:8000/api/monitor/drift
