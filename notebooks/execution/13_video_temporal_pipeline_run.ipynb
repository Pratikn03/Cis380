# %% [markdown]
# # Execution: Video Temporal Pipeline
#
# Run video temporal training and validate inference.

# %% [markdown]
# ## Inputs
# - src/train/train_video_temporal.py
# - app/api/vision_temporal.py

# %% [markdown]
# ## Outputs
# - Video metrics
# - Temporal prediction

# %% [markdown]
# ## Steps
# 1. Train video model
# 2. Review metrics
# 3. Call temporal endpoint

# %%
# TODO: python src/train/train_video_temporal.py
# TODO: curl -X POST http://localhost:8000/api/vision-temporal/predict -F file=@video.mp4
