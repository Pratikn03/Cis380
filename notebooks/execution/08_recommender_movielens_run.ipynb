# %% [markdown]
# # Execution: Recommender MovieLens
#
# Build MovieLens recommender and validate outputs.

# %% [markdown]
# ## Inputs
# - src/train/train_movielens_recommender.py
# - app/api/recommender.py

# %% [markdown]
# ## Outputs
# - Recommender metrics
# - Top-N results

# %% [markdown]
# ## Steps
# 1. Train recommender
# 2. Review metrics
# 3. Call recommender endpoint

# %%
# TODO: python src/train/train_movielens_recommender.py
# TODO: curl -X POST http://localhost:8000/api/recommender/recommend -H 'Content-Type: application/json' -d '{"user_id":1}'
