# %% [markdown]
# # Execution: NLP Intent Pipeline
#
# Train intent model and validate classification outputs.

# %% [markdown]
# ## Inputs
# - src/uais_v/training/train_nlp.py
# - app/models/nlp

# %% [markdown]
# ## Outputs
# - NLP metrics
# - Classification outputs

# %% [markdown]
# ## Steps
# 1. Train NLP model
# 2. Review metrics
# 3. Test intent classification

# %%
# TODO: python src/uais_v/training/train_nlp.py
# TODO: python - <<'PY'
from app.models.nlp import intent_classifier
PY
