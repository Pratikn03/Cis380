# %% [markdown]
# # Execution: DSA RAG Pipeline
#
# Index DSA docs and validate DSA RAG responses.

# %% [markdown]
# ## Inputs
# - app/rag_dsa/pipeline.py
# - app/api/dsa_rag.py

# %% [markdown]
# ## Outputs
# - Index stats
# - DSA response

# %% [markdown]
# ## Steps
# 1. Build index
# 2. Ask DSA question
# 3. Review citations

# %%
# TODO: python -m app.rag_dsa.build_index
# TODO: curl -X POST http://localhost:8000/api/dsa-rag/ask -H 'Content-Type: application/json' -d '{"query":"Explain LCA"}'
