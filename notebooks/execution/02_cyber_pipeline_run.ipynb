# %% [markdown]
# # Execution: Cyber Pipeline Run
#
# Run cyber model training and validate sample scoring.

# %% [markdown]
# ## Inputs
# - configs/cyber_baseline.yaml
# - src/train/train_cyber.py
# - app/api/cyber_timeline.py

# %% [markdown]
# ## Outputs
# - Cyber metrics
# - Sample events response

# %% [markdown]
# ## Steps
# 1. Train model
# 2. Review metrics
# 3. Call cyber endpoints

# %%
# TODO: python src/train/train_cyber.py --config configs/cyber_baseline.yaml
# TODO: curl -s http://localhost:8000/api/cyber/events
