# %% [markdown]
# # Execution: Behavior Pipeline Run
#
# Run behavior model training and validate inference outputs.

# %% [markdown]
# ## Inputs
# - configs/behavior_config.yaml
# - src/train/train_behavior.py
# - app/api/behavior.py

# %% [markdown]
# ## Outputs
# - Behavior metrics
# - Sample anomaly score

# %% [markdown]
# ## Steps
# 1. Train model
# 2. Review metrics
# 3. Call behavior endpoint

# %%
# TODO: python src/train/train_behavior.py --config configs/behavior_config.yaml
# TODO: curl -X POST http://localhost:8000/api/behavior -H 'Content-Type: application/json' -d '{"features":[0.1,0.2,0.3]}'
