# %% [markdown]
# # Execution: STT/TTS Pipeline
#
# Verify STT and TTS endpoints with sample audio/text.

# %% [markdown]
# ## Inputs
# - app/api/stt.py
# - app/api/tts.py

# %% [markdown]
# ## Outputs
# - Transcript
# - Audio response

# %% [markdown]
# ## Steps
# 1. Call STT endpoint
# 2. Call TTS endpoint
# 3. Record outputs

# %%
# TODO: curl -X POST http://localhost:8000/api/stt/transcribe -F file=@sample.wav
# TODO: curl -X POST http://localhost:8000/api/tts/speak -H 'Content-Type: application/json' -d '{"text":"Hello"}'
