# %% [markdown]
# # Training: Supervised Behavior
#
# Train supervised behavior model and record metrics.

# %% [markdown]
# ## Inputs
# - configs/behavior_config.yaml
# - src/train/train_behavior.py

# %% [markdown]
# ## Outputs
# - Trained model
# - Metrics JSON

# %% [markdown]
# ## Steps
# 1. Run training
# 2. Capture metrics
# 3. Save artifacts

# %%
# TODO: python src/train/train_behavior.py --config configs/behavior_config.yaml
