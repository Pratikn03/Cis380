# %% [markdown]
# # Training: DSA RAG Pipeline
#
# Index DSA docs and validate retrieval pipeline.

# %% [markdown]
# ## Inputs
# - app/rag/dsa_pipeline.py
# - data/dsa_docs

# %% [markdown]
# ## Outputs
# - Index artifacts
# - Sample queries

# %% [markdown]
# ## Steps
# 1. Run DSA ingest
# 2. Run sample queries

# %%
# TODO: python -m app.rag_dsa.build_index
