# %% [markdown]
# # Training: STT/TTS Pipeline
#
# Document speech pipeline configuration and any fine-tuning steps.

# %% [markdown]
# ## Inputs
# - app/services/stt
# - app/api/stt.py
# - app/api/tts.py

# %% [markdown]
# ## Outputs
# - Speech pipeline notes
# - Config references

# %% [markdown]
# ## Steps
# 1. Review STT/TTS services
# 2. Record dependencies
# 3. Note model assets

# %%
# TODO: inspect app/services/stt and app/api/stt.py
