# %% [markdown]
# # EDA: Recommender (MovieLens)
#
# Inspect MovieLens dataset structure and basic stats.

# %% [markdown]
# ## Inputs
# - data/raw/recommendation
# - data/raw/recommender

# %% [markdown]
# ## Outputs
# - Ratings counts
# - User/item distribution

# %% [markdown]
# ## Steps
# 1. Load ratings file
# 2. Compute basic counts

# %%
# TODO: load MovieLens ratings CSV
