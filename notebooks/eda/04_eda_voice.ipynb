# %% [markdown]
# # EDA: Voice Dataset
#
# Inspect voice dataset class balance and file counts.

# %% [markdown]
# ## Inputs
# - data/raw/voice

# %% [markdown]
# ## Outputs
# - Class counts
# - File samples

# %% [markdown]
# ## Steps
# 1. Count files per class
# 2. Inspect file durations (optional)

# %%
from pathlib import Path
root = Path('data/raw/voice')
print([p.name for p in root.iterdir() if p.is_dir()])
