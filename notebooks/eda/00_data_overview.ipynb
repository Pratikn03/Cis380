# %%
from pathlib import Path
import sys

import numpy as np
import pandas as pd

# Navigate to project root (notebooks/eda -> project root)
project_root = Path('../..').resolve()
print('Project root:', project_root)

src_path = project_root / 'src'
if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from uais.data.load_fraud_data import load_fraud_data
# Out:
# Project root: /Users/pratik_n/Desktop/MyComputer/Sentifargo

# %%
print('Folders in project root:')
for p in project_root.iterdir():
    if p.is_dir():
        print(' -', p.name)

fraud_raw_dir = project_root / 'data' / 'raw' / 'fraud'
print('Fraud raw directory:', fraud_raw_dir)
print('Exists:', fraud_raw_dir.exists())

if fraud_raw_dir.exists():
    print('Files in data/raw/fraud:')
    for f in fraud_raw_dir.iterdir():
        print(' -', f.name)
# Out:
# Folders in project root:
#  - ui-web
#  - artifacts
#  - app
#  - deploy
#  - experiments
#  - mlops
#  - .dvc
#  - tests
#  - models
#  - docs
#  - dashboard
#  - logs
#  - benchmarks
#  - configs
#  - .venv
#  - scripts
#  - .github
#  - .git
#  - .vscode
#  - data
#  - runs
#  - notebooks
#  - reports
#  - src
# Fraud raw directory: /Users/pratik_n/Desktop/MyComputer/Sentifargo/data/raw/fraud
# Exists: True
# Files in data/raw/fraud:
#  - paysim
#  - creditcard.csv

# %%
df_raw = load_fraud_data()
print('Raw fraud data shape:', df_raw.shape)
df_raw.head()
# Out:
# Raw fraud data shape: (6647427, 40)
#    step      type    Amount     nameorig  oldbalanceorg  newbalanceorig  \
# 0   1.0   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1   1.0   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2   1.0  TRANSFER    181.00  C1305486145          181.0            0.00
# 3   1.0  CASH_OUT    181.00   C840083671          181.0            0.00
# 4   1.0   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       namedest  oldbalancedest  newbalancedest  Class  ...  V19  V20  V21  \
# 0  M1979787155             0.0             0.0      0  ...  NaN  NaN  NaN
# 1  M2044282225             0.0             0.0      0  ...  NaN  NaN  NaN
# 2   C553264065             0.0             0.0      1  ...  NaN  NaN  NaN
# 3    C38997010         21182.0             0.0      1  ...  NaN  NaN  NaN
# 4  M1230701703             0.0             0.0      0  ...  NaN  NaN  NaN
#
#    V22  V23  V24  V25  V26  V27  V28
# ...
