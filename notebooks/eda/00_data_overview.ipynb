# %% [markdown]
# # Data Overview
#
# Auto-generated notebook for Data Overview.

# %%
from __future__ import annotations

import os
import sys
import subprocess
from pathlib import Path

# Find repo root from the notebook location.
PROJECT_ROOT = Path.cwd()
for parent in [PROJECT_ROOT] + list(PROJECT_ROOT.parents):
    if (parent / "scripts").exists() and (parent / "notebooks").exists():
        PROJECT_ROOT = parent
        break

# Ensure local imports work.
sys.path.insert(0, str(PROJECT_ROOT))
sys.path.insert(0, str(PROJECT_ROOT / "src"))


def run(cmd: list[str]) -> None:
    # Run a subprocess from repo root with PYTHONPATH set.
    env = os.environ.copy()
    paths = [str(PROJECT_ROOT / "src"), str(PROJECT_ROOT)]
    if env.get("PYTHONPATH"):
        paths.append(env["PYTHONPATH"])
    env["PYTHONPATH"] = os.pathsep.join(paths)
    print("$", " ".join(cmd))
    subprocess.run(cmd, cwd=str(PROJECT_ROOT), check=True, env=env)

# %%
import pandas as pd
from pathlib import Path

paths = [
    PROJECT_ROOT / 'data/raw',
]

for path in paths:
    print(f'\nInspecting: {path}')
    if path.is_dir():
        files = [p for p in path.rglob('*') if p.is_file()]
        print('File count:', len(files))
        for sample in files[:5]:
            print(' -', sample.relative_to(PROJECT_ROOT))
        continue
    if not path.exists():
        print('Missing:', path)
        continue
    suffix = path.suffix.lower()
    if suffix in {'.csv', '.tsv'}:
        df = pd.read_csv(path, nrows=5000)
        print('Shape:', df.shape)
        print(df.head())
        print(df.describe(include='all').transpose().head(20))
    elif suffix in {'.json', '.jsonl'}:
        df = pd.read_json(path, lines=True)
        print('Shape:', df.shape)
        print(df.head())
    else:
        print('File exists:', path)
# Out:
# Inspecting: /Users/pratik_n/Desktop/MyComputer/universal-anomaly-intelligence-v2/data/raw
# File count: 768802
#  - data/raw/.DS_Store
#  - data/raw/behavior/online_shoppers_intention.csv
#  - data/raw/behavior/r4.2.tar.bz2
#  - data/raw/behavior/r4.2/device.csv
#  - data/raw/behavior/r4.2/psychometric.csv

# %%
# Run the pipeline commands in order.
PY = sys.executable
commands = [
    [PY, 'scripts/training_data_audit.py'],
]
for cmd in commands:
    run(cmd)
# Out:
# $ PY scripts/training_data_audit.py
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 7
#       3 commands = [
#       4     ['PY', 'scripts/training_data_audit.py'],
#       5 ]
#       6 for cmd in commands:
# ----> 7     run(cmd)
#
# Cell In[1], line 28, in run(cmd)
#      26 env["PYTHONPATH"] = os.pathsep.join(paths)
#      27 print("$", " ".join(cmd))
# ---> 28 subprocess.run(cmd, cwd=str(PROJECT_ROOT), check=True, env=env)
#
# File /opt/anaconda3/envs/automl311/lib/python3.11/subprocess.py:548, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     545     kwargs['stdout'] = PIPE
#     546     kwargs['stderr'] = PIPE
# --> 548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
#     550         stdout, stderr = process.communicate(input, timeout=timeout)
#
# File /opt/anaconda3/envs/automl311/lib/python3.11/subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session, process_group)
#    1022         if self.text_mode:
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#    1037     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File /opt/anaconda3/envs/automl311/lib/python3.11/subprocess.py:1955, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session, process_group)
#    1953     err_msg = os.strerror(errno_num)
#    1954 if err_filename is not None:
# -> 1955     raise child_exception_type(errno_num, err_msg, err_filename)
#    1956 else:
#    1957     raise child_exception_type(errno_num, err_msg)

# %%
from pathlib import Path

for folder in ["models", "experiments", "artifacts", "runs", "reports", "logs"]:
    path = PROJECT_ROOT / folder
    if not path.exists():
        continue
    print(f"
{folder}/")
    for item in sorted(path.iterdir())[:20]:
        print(" -", item.name)
