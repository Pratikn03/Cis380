# %% [markdown]
# # Showcase: Chat Orchestration
#
# Show end-to-end routing across modules in the chat interface.

# %% [markdown]
# ## Inputs
# - /api/chat
# - app/agent/orchestrator.py

# %% [markdown]
# ## Outputs
# - Demo transcript

# %% [markdown]
# ## Steps
# 1. Send representative queries
# 2. Capture responses

# %%
# TODO: call /api/chat and save outputs
