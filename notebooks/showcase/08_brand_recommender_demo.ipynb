# %% [markdown]
# # Showcase: Brand to Recommendation
#
# Show brand detection feeding recommendation results.

# %% [markdown]
# ## Inputs
# - /api/brand/predict
# - /api/recommender/multimodal

# %% [markdown]
# ## Outputs
# - Brand detections
# - Recommendation list

# %% [markdown]
# ## Steps
# 1. Detect brand
# 2. Use brand in recommender

# %%
# TODO: call brand endpoint, then recommender endpoint
