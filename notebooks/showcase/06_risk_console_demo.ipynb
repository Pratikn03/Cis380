# %% [markdown]
# # Showcase: Risk Console
#
# Demonstrate fraud/cyber/behavior risk outputs.

# %% [markdown]
# ## Inputs
# - /api/risk/analyze
# - app/services/risk_engine.py

# %% [markdown]
# ## Outputs
# - Risk console outputs

# %% [markdown]
# ## Steps
# 1. Submit risk payloads
# 2. Capture responses

# %%
# TODO: call /api/risk/analyze with a sample payload
