# %% [markdown]
# # Showcase: Voice STT/TTS
#
# Demonstrate STT + TTS workflow in the UI.

# %% [markdown]
# ## Inputs
# - /api/stt/transcribe
# - /api/tts/speak

# %% [markdown]
# ## Outputs
# - Voice demo outputs

# %% [markdown]
# ## Steps
# 1. Upload audio
# 2. Play TTS output

# %%
# TODO: call /api/stt/transcribe and /api/tts/speak
