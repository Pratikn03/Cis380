# %% [markdown]
# # UI Walkthrough: Next.js Login
#
# Document login flow and token storage.

# %% [markdown]
# ## Inputs
# - ui-web/next
# - /api/v1/auth/login

# %% [markdown]
# ## Outputs
# - Screenshots
# - Token notes

# %% [markdown]
# ## Steps
# 1. Open Login
# 2. Authenticate
# 3. Verify token

# %%
# TODO: record screenshot to docs/screenshots/login.png
