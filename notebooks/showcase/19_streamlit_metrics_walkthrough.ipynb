# %% [markdown]
# # UI Walkthrough: Streamlit Metrics
#
# Document metrics dashboard outputs.

# %% [markdown]
# ## Inputs
# - app/streamlit_chatbot/pages/metrics.py

# %% [markdown]
# ## Outputs
# - Screenshots
# - Metrics notes

# %% [markdown]
# ## Steps
# 1. Open Metrics page
# 2. Review charts
# 3. Capture screen

# %%
# TODO: open Streamlit metrics page
