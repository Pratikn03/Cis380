# %% [markdown]
# # UI Walkthrough: Next.js Risk
#
# Document Risk page flow and outputs.

# %% [markdown]
# ## Inputs
# - ui-web/next
# - /api/risk/analyze

# %% [markdown]
# ## Outputs
# - Screenshots
# - Risk notes

# %% [markdown]
# ## Steps
# 1. Open Risk page
# 2. Submit sample payload
# 3. Capture output

# %%
# TODO: record screenshot to docs/screenshots/risk.png
