# %% [markdown]
# # Showcase: Multimodal Vision
#
# Demonstrate vision + brand pipeline on sample images.

# %% [markdown]
# ## Inputs
# - /api/vision/*
# - /api/brand/predict

# %% [markdown]
# ## Outputs
# - Detection results
# - Recommendations

# %% [markdown]
# ## Steps
# 1. Upload image
# 2. Record outputs

# %%
# TODO: call vision and brand endpoints with sample image
