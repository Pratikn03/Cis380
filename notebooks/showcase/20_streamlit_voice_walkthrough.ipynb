# %% [markdown]
# # UI Walkthrough: Streamlit Voice
#
# Document voice chat workflow in Streamlit.

# %% [markdown]
# ## Inputs
# - app/streamlit_chatbot/pages/voice_chat.py

# %% [markdown]
# ## Outputs
# - Screenshots
# - Voice notes

# %% [markdown]
# ## Steps
# 1. Open Voice page
# 2. Send prompt
# 3. Capture output

# %%
# TODO: open Streamlit voice page
