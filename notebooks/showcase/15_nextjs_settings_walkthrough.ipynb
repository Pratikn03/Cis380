# %% [markdown]
# # UI Walkthrough: Next.js Settings
#
# Document Settings page flow and saved config.

# %% [markdown]
# ## Inputs
# - ui-web/next

# %% [markdown]
# ## Outputs
# - Screenshots
# - Settings notes

# %% [markdown]
# ## Steps
# 1. Open Settings
# 2. Update API base
# 3. Capture screen

# %%
# TODO: record screenshot to docs/screenshots/settings.png
