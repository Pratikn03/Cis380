# %% [markdown]
# # UI Walkthrough: Next.js Jobs
#
# Document Jobs page flow and async job behavior.

# %% [markdown]
# ## Inputs
# - ui-web/next
# - /api/v1/jobs

# %% [markdown]
# ## Outputs
# - Screenshots
# - Job notes

# %% [markdown]
# ## Steps
# 1. Open Jobs
# 2. Start rag_index job
# 3. Capture status

# %%
# TODO: record screenshot to docs/screenshots/jobs.png
