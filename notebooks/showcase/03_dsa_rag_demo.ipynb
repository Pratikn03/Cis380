# %% [markdown]
# # Showcase: DSA RAG Demo
#
# Demonstrate DSA RAG answers with citations.

# %% [markdown]
# ## Inputs
# - /api/dsa-rag/ask
# - data/dsa_docs

# %% [markdown]
# ## Outputs
# - Sample answers
# - Citation screenshots

# %% [markdown]
# ## Steps
# 1. Ask DSA queries
# 2. Capture answers

# %%
# TODO: curl -X POST http://localhost:8000/api/dsa-rag/ask ...
