# %% [markdown]
# # UI Walkthrough: Next.js Dashboard
#
# Document the Dashboard page flow and expected outputs.

# %% [markdown]
# ## Inputs
# - ui-web/next
# - /api/health
# - /api/monitor/summary

# %% [markdown]
# ## Outputs
# - Screenshots
# - Notes

# %% [markdown]
# ## Steps
# 1. Open Dashboard
# 2. Verify health card
# 3. Capture screenshot

# %%
# TODO: record screenshot to docs/screenshots/dashboard.png
