# %% [markdown]
# # UI Walkthrough: Next.js Models
#
# Document Models page flow and registry outputs.

# %% [markdown]
# ## Inputs
# - ui-web/next
# - /api/v1/models

# %% [markdown]
# ## Outputs
# - Screenshots
# - Registry notes

# %% [markdown]
# ## Steps
# 1. Open Models page
# 2. Review model list
# 3. Capture output

# %%
# TODO: record screenshot to docs/screenshots/models.png
