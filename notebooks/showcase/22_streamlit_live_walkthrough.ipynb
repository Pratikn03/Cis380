# %% [markdown]
# # UI Walkthrough: Streamlit Live
#
# Document live mic + webcam page behavior.

# %% [markdown]
# ## Inputs
# - app/streamlit_chatbot/pages/live.py

# %% [markdown]
# ## Outputs
# - Screenshots
# - Latency notes

# %% [markdown]
# ## Steps
# 1. Open Live page
# 2. Record snapshot audio/image
# 3. Run multimodal chat

# %%
# TODO: open Streamlit live page
