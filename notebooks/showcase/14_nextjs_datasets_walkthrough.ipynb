# %% [markdown]
# # UI Walkthrough: Next.js Datasets
#
# Document Datasets page flow and dataset metadata.

# %% [markdown]
# ## Inputs
# - ui-web/next
# - /api/v1/datasets

# %% [markdown]
# ## Outputs
# - Screenshots
# - Dataset notes

# %% [markdown]
# ## Steps
# 1. Open Datasets page
# 2. Review catalog
# 3. Capture output

# %%
# TODO: record screenshot to docs/screenshots/datasets.png
