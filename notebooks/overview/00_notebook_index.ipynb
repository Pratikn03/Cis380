# %% [markdown]
# # Sentifargo Notebook Index

# %% [markdown]
# This index maps notebooks to the core modules in the project. Use it as the entry point for training, evaluation, and demo workflows.

# %% [markdown]
# ## Project idea

# %% [markdown]
# Sentifargo is a multimodal AI system that combines fraud, cyber, and behavior risk scoring with vision, voice emotion, brand/logo detection, and retrieval-augmented answers.

# %% [markdown]
# ## Training notebooks

# %% [markdown]
# - Fraud (supervised): `notebooks/training/10_supervised_fraud.ipynb`

# %% [markdown]
# - Cyber (supervised): `notebooks/training/11_supervised_cyber.ipynb`

# %% [markdown]
# - Fraud (unsupervised): `notebooks/training/20_unsupervised_fraud.ipynb`

# %% [markdown]
# - Cyber (unsupervised): `notebooks/training/21_unsupervised_cyber.ipynb`

# %% [markdown]
# - Behavior (unsupervised): `notebooks/training/22_unsupervised_behavior.ipynb`

# %% [markdown]
# - Fusion model: `notebooks/training/40_fusion_model.ipynb`

# %% [markdown]
# - Hybrid fraud scoring: `notebooks/training/40_hybrid_fraud_score.ipynb`

# %% [markdown]
# - NLP anomalies: `notebooks/training/70_nlp_email_anomalies.ipynb`

# %% [markdown]
# - Vision forgery: `notebooks/training/80_vision_forgery_detection.ipynb`

# %% [markdown]
# - Face emotion: `notebooks/training/81_face_emotion.ipynb`

# %% [markdown]
# - Brand logo YOLO: `notebooks/training/82_brand_logo_yolo.ipynb`

# %% [markdown]
# - Voice emotion: `notebooks/training/83_voice_emotion.ipynb`

# %% [markdown]
# - MovieLens recommender: `notebooks/training/84_recommender_movielens.ipynb`

# %% [markdown]
# - Multimodal index: `notebooks/training/85_recommender_multimodal_index.ipynb`

# %% [markdown]
# - RAG ingest/query: `notebooks/training/86_rag_ingest_query.ipynb`

# %% [markdown]
# - Video temporal: `notebooks/training/87_video_temporal.ipynb`

# %% [markdown]
# - Risk action recommender: `notebooks/training/88_action_recommender.ipynb`

# %% [markdown]
# ## Evaluation notebooks
#
# - Metrics readiness audit: `notebooks/evaluation/98_metrics_audit.ipynb`
# - Voice metrics: `notebooks/evaluation/70_voice_metrics.ipynb`
# - Video metrics: `notebooks/evaluation/71_video_metrics.ipynb`
# - Recommender metrics: `notebooks/evaluation/72_recommender_metrics.ipynb`

# %% [markdown]
# - Explainability: `notebooks/evaluation/50_explainability.ipynb`

# %% [markdown]
# - Drift evaluation: `notebooks/evaluation/60_evaluation_drift.ipynb`

# %% [markdown]
# - Reports preview: `notebooks/evaluation/96_reports_preview.ipynb`

# %% [markdown]
# - Feature ablation: `notebooks/evaluation/97_feature_ablation.ipynb`

# %% [markdown]
# ## EDA notebooks

# %% [markdown]
# - Data overview: `notebooks/eda/00_data_overview.ipynb`

# %% [markdown]
# - Fraud EDA: `notebooks/eda/01_eda_fraud.ipynb`

# %% [markdown]
# - Cyber EDA: `notebooks/eda/02_eda_cyber.ipynb`

# %% [markdown]
# - Behavior EDA: `notebooks/eda/03_eda_behavior.ipynb`

# %% [markdown]
# - Behavior EDA (cert): `notebooks/eda/03_eda_behavior_cert.ipynb`

# %% [markdown]
# - Quickstart: `notebooks/eda/95_data_quickstart.ipynb`

# %% [markdown]
# ## Programmatic listing (auto)

# %% [markdown]
# ## New notebooks added (2026-01-21)
#
# - `notebooks/overview/01_api_contracts_v1.ipynb`
# - `notebooks/overview/02_jobs_workers_pipeline.ipynb`
# - `notebooks/overview/03_data_catalog_dvc.ipynb`
# - `notebooks/overview/04_security_rbac_audit.ipynb`
# - `notebooks/overview/05_observability_metrics.ipynb`
# - `notebooks/overview/06_ci_cd_pipeline.ipynb`
# - `notebooks/eda/04_eda_voice.ipynb`
# - `notebooks/eda/05_eda_vision_deepfake.ipynb`
# - `notebooks/eda/06_eda_brand_logo.ipynb`
# - `notebooks/eda/07_eda_recommender_movielens.ipynb`
# - `notebooks/eda/08_eda_recommender_multimodal.ipynb`
# - `notebooks/eda/09_eda_rag_docs.ipynb`
# - `notebooks/eda/10_eda_dsa_docs.ipynb`
# - `notebooks/eda/11_eda_monitoring_logs.ipynb`
# - `notebooks/training/12_supervised_behavior.ipynb`
# - `notebooks/training/41_fusion_meta_model.ipynb`
# - `notebooks/training/89_dsa_rag_pipeline.ipynb`
# - `notebooks/training/93_brand_multiclass_yolo.ipynb`
# - `notebooks/evaluation/73_rag_eval.ipynb`
# - `notebooks/evaluation/74_dsa_rag_eval.ipynb`
# - `notebooks/evaluation/75_model_registry_audit.ipynb`
# - `notebooks/evaluation/76_system_scorecard.ipynb`
# - `notebooks/evaluation/77_contract_gate.ipynb`
# - `notebooks/showcase/03_dsa_rag_demo.ipynb`
# - `notebooks/showcase/04_multimodal_vision_demo.ipynb`

# %% [markdown]
# ## Additional notebooks added (2026-01-21, batch 2)
#
# - `notebooks/overview/07_system_architecture_map.ipynb`
# - `notebooks/overview/08_api_route_matrix.ipynb`
# - `notebooks/overview/09_notebook_coverage_audit.ipynb`
# - `notebooks/overview/10_release_checklist.ipynb`
# - `notebooks/eda/12_eda_nlp_text.ipynb`
# - `notebooks/eda/13_eda_video_temporal.ipynb`
# - `notebooks/training/94_stt_tts_pipeline.ipynb`
# - `notebooks/training/95_risk_engine_calibration.ipynb`
# - `notebooks/evaluation/78_dsa_algorithms_api.ipynb`
# - `notebooks/evaluation/79_chat_orchestrator_eval.ipynb`
# - `notebooks/evaluation/80_voice_stt_tts_eval.ipynb`
# - `notebooks/evaluation/81_vision_brand_eval.ipynb`
# - `notebooks/showcase/05_chat_orchestration_demo.ipynb`
# - `notebooks/showcase/06_risk_console_demo.ipynb`
# - `notebooks/showcase/07_voice_stt_tts_demo.ipynb`
# - `notebooks/showcase/08_brand_recommender_demo.ipynb`

# %% [markdown]
# ## Additional notebooks added (2026-01-21, batch 3)
#
# - `notebooks/execution/01_fraud_pipeline_run.ipynb`
# - `notebooks/execution/02_cyber_pipeline_run.ipynb`
# - `notebooks/execution/03_behavior_pipeline_run.ipynb`
# - `notebooks/execution/04_fusion_pipeline_run.ipynb`
# - `notebooks/execution/05_vision_pipeline_run.ipynb`
# - `notebooks/execution/06_voice_pipeline_run.ipynb`
# - `notebooks/execution/07_brand_yolo_pipeline_run.ipynb`
# - `notebooks/execution/08_recommender_movielens_run.ipynb`
# - `notebooks/execution/09_recommender_multimodal_run.ipynb`
# - `notebooks/execution/10_rag_pipeline_run.ipynb`
# - `notebooks/execution/11_dsa_rag_pipeline_run.ipynb`
# - `notebooks/execution/12_nlp_intent_pipeline_run.ipynb`
# - `notebooks/execution/13_video_temporal_pipeline_run.ipynb`
# - `notebooks/execution/14_stt_tts_pipeline_run.ipynb`
# - `notebooks/execution/15_monitoring_drift_pipeline_run.ipynb`
# - `notebooks/eda/14_eda_fraud_splits.ipynb`
# - `notebooks/eda/15_eda_cyber_splits.ipynb`
# - `notebooks/eda/16_eda_behavior_splits.ipynb`
# - `notebooks/eda/17_eda_voice_splits.ipynb`
# - `notebooks/eda/18_eda_vision_splits.ipynb`
# - `notebooks/eda/19_eda_brand_splits.ipynb`
# - `notebooks/eda/20_eda_recommender_splits.ipynb`
# - `notebooks/eda/21_eda_rag_doc_stats.ipynb`
# - `notebooks/eda/22_eda_dsa_doc_stats.ipynb`
# - `notebooks/eda/23_eda_datasets_inventory.ipynb`
# - `notebooks/showcase/09_nextjs_dashboard_walkthrough.ipynb`
# - `notebooks/showcase/10_nextjs_jobs_walkthrough.ipynb`
# - `notebooks/showcase/11_nextjs_rag_walkthrough.ipynb`
# - `notebooks/showcase/12_nextjs_risk_walkthrough.ipynb`
# - `notebooks/showcase/13_nextjs_models_walkthrough.ipynb`
# - `notebooks/showcase/14_nextjs_datasets_walkthrough.ipynb`
# - `notebooks/showcase/15_nextjs_settings_walkthrough.ipynb`
# - `notebooks/showcase/16_nextjs_login_walkthrough.ipynb`
# - `notebooks/showcase/17_streamlit_chat_walkthrough.ipynb`
# - `notebooks/showcase/18_streamlit_command_center_walkthrough.ipynb`
# - `notebooks/showcase/19_streamlit_metrics_walkthrough.ipynb`
# - `notebooks/showcase/20_streamlit_voice_walkthrough.ipynb`

# %% [markdown]
# ## Additional notebooks added (2026-01-21, batch 4)
#
# - `notebooks/showcase/21_streamlit_brand_walkthrough.ipynb`
# - `notebooks/showcase/22_streamlit_live_walkthrough.ipynb`
# - `notebooks/showcase/23_streamlit_risk_walkthrough.ipynb`
# - `notebooks/showcase/24_streamlit_tools_walkthrough.ipynb`

# %% [markdown]
# ## Additional notebooks added (2026-01-21, batch 5)
#
# - `notebooks/overview/11_agent_orchestrator.ipynb`
# - `notebooks/overview/12_monitoring_alerts.ipynb`
# - `notebooks/overview/13_rag_pipeline_map.ipynb`
# - `notebooks/overview/14_dsa_rag_pipeline_map.ipynb`
# - `notebooks/overview/15_services_workers.ipynb`
# - `notebooks/overview/16_data_db_schema.ipynb`
# - `notebooks/overview/17_mlops_registry.ipynb`
# - `notebooks/overview/18_dsa_algorithms_map.ipynb`
# - `notebooks/overview/19_legacy_migration_map.ipynb`
# - `notebooks/overview/20_recommender_stack.ipynb`
# - `notebooks/overview/21_vision_voice_stack.ipynb`
# - `notebooks/experiments/01_experiments_index.ipynb`
# - `notebooks/experiments/02_fraud_experiments_review.ipynb`
# - `notebooks/experiments/03_cyber_experiments_review.ipynb`
# - `notebooks/experiments/04_behavior_experiments_review.ipynb`
# - `notebooks/experiments/05_fusion_experiments_review.ipynb`
# - `notebooks/experiments/06_vision_experiments_review.ipynb`
# - `notebooks/experiments/07_recommender_experiments_review.ipynb`
# - `notebooks/experiments/08_generative_experiments_review.ipynb`

# %% [markdown]
# ## Additional notebooks added (2026-01-21, batch 6)
#
# - `notebooks/overview/22_core_runtime_config.ipynb`
# - `notebooks/overview/23_api_modules_map.ipynb`
# - `notebooks/overview/24_fusion_engine_runtime.ipynb`
# - `notebooks/overview/25_chatbot_stack_overview.ipynb`
# - `notebooks/overview/26_vision_local_tools.ipynb`
# - `notebooks/overview/27_data_generation_tools.ipynb`
# - `notebooks/overview/28_deployment_runtime.ipynb`
# - `notebooks/overview/29_quality_gates_testing.ipynb`
# - `notebooks/overview/30_orchestration_pipelines.ipynb`

# %%
from pathlib import Path

root = Path.cwd().resolve()
for cand in [root, *root.parents]:
    if (cand / 'notebooks').exists():
        root = cand
        break

for section in ['eda', 'training', 'evaluation', 'overview']:
    print('##', section)
    for p in sorted((root / 'notebooks' / section).glob('*.ipynb')):
        print('-', p.name)
# Out:
# ## eda
# - 00_data_overview.ipynb
# - 01_eda_fraud.ipynb
# - 02_eda_cyber.ipynb
# - 03_eda_behavior.ipynb
# - 03_eda_behavior_cert.ipynb
# - 95_data_quickstart.ipynb
# ## training
# - 10_supervised_fraud.ipynb
# - 11_supervised_cyber.ipynb
# - 20_unsupervised_fraud.ipynb
# - 21_unsupervised_cyber.ipynb
# - 22_unsupervised_behavior.ipynb
# - 30_sequence_models.ipynb
# - 40_fusion_model.ipynb
# - 40_hybrid_fraud_score.ipynb
# - 70_nlp_email_anomalies.ipynb
# - 80_vision_forgery_detection.ipynb
# - 81_face_emotion.ipynb
# - 82_brand_logo_yolo.ipynb
# - 83_voice_emotion.ipynb
# - 84_recommender_movielens.ipynb
# - 85_recommender_multimodal_index.ipynb
# - 86_rag_ingest_query.ipynb
# - 87_video_temporal.ipynb
# - 88_action_recommender.ipynb
# - 90_generative_synthesis.ipynb
# ## evaluation
# - 50_explainability.ipynb
# - 60_evaluation_drift.ipynb
# - 96_reports_preview.ipynb
# - 97_feature_ablation.ipynb
# ## overview
# - 00_notebook_index.ipynb
# - 100_fusion_and_dashboard.ipynb
# ...
