# %% [markdown]
# # RAG Pipeline Map
#
# Trace the general RAG pipeline and ingestion flow.

# %% [markdown]
# ## Inputs
# - app/rag
# - app/api/rag.py
# - data/docs

# %% [markdown]
# ## Outputs
# - RAG pipeline map
# - Ingest steps summary
# - Query response schema

# %% [markdown]
# ## Steps
# 1. Identify ingestion entrypoints
# 2. Review retrieval pipeline
# 3. Record response fields

# %%
# TODO: document RAG pipeline
