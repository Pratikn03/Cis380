# %% [markdown]
# # Data + DB Schema Overview
#
# Document data models and database session setup.

# %% [markdown]
# ## Inputs
# - app/db/models.py
# - app/db/session.py
# - alembic

# %% [markdown]
# ## Outputs
# - DB schema summary
# - Session/engine config notes
# - Migration checklist

# %% [markdown]
# ## Steps
# 1. List models and tables
# 2. Review session configuration
# 3. Note migration commands

# %%
# TODO: inspect DB models and migrations
