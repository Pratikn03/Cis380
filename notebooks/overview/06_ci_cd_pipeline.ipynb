# %% [markdown]
# # CI/CD Pipeline Overview
#
# Summarize CI jobs, gating rules, and release steps.

# %% [markdown]
# ## Inputs
# - .github/workflows
# - scripts/ci_*

# %% [markdown]
# ## Outputs
# - CI job map
# - Known gating rules

# %% [markdown]
# ## Steps
# 1. List workflows
# 2. Record job order
# 3. Note required checks

# %%
from pathlib import Path
print(list(Path('.github/workflows').glob('*.yml')))
