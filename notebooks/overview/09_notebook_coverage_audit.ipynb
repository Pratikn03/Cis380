# %% [markdown]
# # Notebook Coverage Audit
#
# Verify that each major module has a corresponding notebook.

# %% [markdown]
# ## Inputs
# - notebooks/overview/00_notebook_index.ipynb
# - app/*

# %% [markdown]
# ## Outputs
# - Coverage checklist
# - Missing notebook list

# %% [markdown]
# ## Steps
# 1. List notebooks
# 2. List modules
# 3. Map coverage gaps

# %%
from pathlib import Path
print(sorted(Path('notebooks').rglob('*.ipynb')))
