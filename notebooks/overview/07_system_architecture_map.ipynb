# %% [markdown]
# # System Architecture Map
#
# Align modules, services, and data flows with the Tier-6 architecture.

# %% [markdown]
# ## Inputs
# - docs/ARCHITECTURE.md
# - app/main.py
# - app/services
# - deploy/*

# %% [markdown]
# ## Outputs
# - Architecture notes
# - Module map

# %% [markdown]
# ## Steps
# 1. Review architecture docs
# 2. Map runtime services
# 3. Record module boundaries

# %%
# TODO: summarize ARCHITECTURE.md and app/main.py
