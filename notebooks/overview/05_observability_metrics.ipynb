# %% [markdown]
# # Observability and Metrics
#
# Confirm metrics endpoints and dashboards are wired.

# %% [markdown]
# ## Inputs
# - /metrics
# - deploy/grafana
# - app/monitoring

# %% [markdown]
# ## Outputs
# - Metrics snapshot
# - Dashboard checklist

# %% [markdown]
# ## Steps
# 1. Fetch /metrics
# 2. Check Grafana dashboards
# 3. Record key panels

# %%
# TODO: curl http://localhost:8000/metrics | head -n 40
