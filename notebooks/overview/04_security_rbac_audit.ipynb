# %% [markdown]
# # Security and RBAC Audit
#
# Verify auth, roles, and audit logging coverage.

# %% [markdown]
# ## Inputs
# - app/core/auth.py
# - app/api/v1/auth.py
# - logs/audit

# %% [markdown]
# ## Outputs
# - Auth flow notes
# - Audit log samples

# %% [markdown]
# ## Steps
# 1. Create or login user
# 2. Call a protected endpoint
# 3. Review audit log entries

# %%
# TODO: login via API and capture token
