# %% [markdown]
# # Legacy Migration Map
#
# Identify legacy modules and migration targets.

# %% [markdown]
# ## Inputs
# - app/legacy
# - app/main.py

# %% [markdown]
# ## Outputs
# - Legacy module inventory
# - Migration candidates list
# - Compatibility notes

# %% [markdown]
# ## Steps
# 1. List legacy modules
# 2. Map current usage
# 3. Define migration plan

# %%
# TODO: audit legacy modules
