# %% [markdown]
# # DSA RAG Pipeline Map
#
# Trace offline-first DSA RAG pipeline and routing.

# %% [markdown]
# ## Inputs
# - app/rag_dsa
# - app/api/dsa_rag.py
# - data/dsa_docs

# %% [markdown]
# ## Outputs
# - DSA RAG pipeline map
# - Offline/online routing notes
# - Index artifacts list

# %% [markdown]
# ## Steps
# 1. Review build_index and pipeline
# 2. Document routing behavior
# 3. Capture inputs and outputs

# %%
# TODO: document DSA RAG pipeline
