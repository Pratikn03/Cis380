# %% [markdown]
# # Recommender Stack Overview
#
# Document recommender inference stack and endpoints.

# %% [markdown]
# ## Inputs
# - app/models/recommender
# - app/api/recommender.py
# - data/catalogs

# %% [markdown]
# ## Outputs
# - Recommender endpoint map
# - Inference flow notes
# - Catalog inputs list

# %% [markdown]
# ## Steps
# 1. Review recommender endpoints
# 2. Trace inference pipeline
# 3. Capture required inputs

# %%
# TODO: document recommender stack
