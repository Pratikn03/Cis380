# %% [markdown]
# # Services + Workers Overview
#
# Summarize async services and worker tasks.

# %% [markdown]
# ## Inputs
# - app/services
# - app/workers

# %% [markdown]
# ## Outputs
# - Worker task inventory
# - Queue and async config notes
# - Job log schema

# %% [markdown]
# ## Steps
# 1. List worker tasks
# 2. Review async worker configuration
# 3. Capture job log outputs

# %%
# TODO: map services and workers
