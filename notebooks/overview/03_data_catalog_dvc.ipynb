# %% [markdown]
# # Data Catalog and DVC
#
# Document dataset locations, sizes, and DVC tracking status.

# %% [markdown]
# ## Inputs
# - data/catalogs
# - .dvc/config
# - dvc.yaml

# %% [markdown]
# ## Outputs
# - Dataset catalog summary
# - DVC status output

# %% [markdown]
# ## Steps
# 1. List catalog files
# 2. Run dvc status
# 3. Check DVC remotes

# %%
from pathlib import Path
catalog_dir = Path('data/catalogs')
print(list(catalog_dir.glob('*')))
