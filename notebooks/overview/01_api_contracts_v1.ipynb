# %% [markdown]
# # API Contracts v1
#
# Map /api/v1 endpoints to modules and verify OpenAPI coverage.

# %% [markdown]
# ## Inputs
# - app/api/v1
# - app/main.py
# - openapi.json
# - scripts/contract_diff.py

# %% [markdown]
# ## Outputs
# - Endpoint map
# - Contract diff report

# %% [markdown]
# ## Steps
# 1. Generate OpenAPI
# 2. Run contract diff
# 3. Review missing/unused routes

# %%
# TODO: run contract diff
# !python scripts/contract_diff.py
