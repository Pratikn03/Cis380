# %% [markdown]
# # Vision + Voice Stack Overview
#
# Document vision and voice inference stacks.

# %% [markdown]
# ## Inputs
# - app/models/vision
# - app/models/video
# - app/models/voice
# - app/api/vision.py
# - app/api/vision_temporal.py
# - app/api/voice.py
# - app/api/stt.py
# - app/api/tts.py

# %% [markdown]
# ## Outputs
# - Vision/voice endpoint map
# - Inference flow notes
# - Model artifact checklist

# %% [markdown]
# ## Steps
# 1. Review vision and voice endpoints
# 2. Trace inference pipelines
# 3. Capture model artifact locations

# %%
# TODO: document vision and voice stack
