# %% [markdown]
# # Quality Gates + Testing
#
# Document CI gates, tests, and audit scripts.

# %% [markdown]
# ## Inputs
# - .github/workflows
# - tests
# - pytest.ini
# - scripts/ci_contract_gate.sh
# - scripts/system_scorecard.py
# - scripts/truth_table_audit.py
# - scripts/full_project_audit.py

# %% [markdown]
# ## Outputs
# - Test inventory
# - CI gate summary
# - Audit script notes

# %% [markdown]
# ## Steps
# 1. Review CI workflows
# 2. Inventory tests and gates
# 3. Record audit outputs

# %%
# TODO: document quality gates and tests
