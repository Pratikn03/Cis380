# %% [markdown]
# # API Route Matrix
#
# Inventory API routes and map them to UI pages and services.

# %% [markdown]
# ## Inputs
# - openapi.json
# - app/api
# - ui-web

# %% [markdown]
# ## Outputs
# - Route matrix
# - Missing route list

# %% [markdown]
# ## Steps
# 1. Export OpenAPI
# 2. Compare with UI usage
# 3. Record mismatches

# %%
# TODO: run scripts/contract_diff.py and review reports/CONTRACT_DIFF.md
