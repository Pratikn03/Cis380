# %% [markdown]
# # Chatbot Stack Overview
#
# Document chatbot routing, handlers, and Streamlit integration.

# %% [markdown]
# ## Inputs
# - app/chatbot
# - app/streamlit_chatbot/unified_chat.py
# - app/streamlit_chatbot/handlers
# - app/api/chat.py

# %% [markdown]
# ## Outputs
# - Chat flow map
# - Handler inventory
# - Fallback behavior notes

# %% [markdown]
# ## Steps
# 1. Review chatbot routing
# 2. List handler modules
# 3. Capture fallback behaviors

# %%
# TODO: map chatbot stack
