# %% [markdown]
# # API Modules Map
#
# Map app/api modules to routes and dependencies.

# %% [markdown]
# ## Inputs
# - app/api
# - app/api/v1
# - app/main.py

# %% [markdown]
# ## Outputs
# - API module inventory
# - Route map
# - Dependency notes

# %% [markdown]
# ## Steps
# 1. List API modules
# 2. Map routes to handlers
# 3. Capture auth/dependency requirements

# %%
# TODO: map API modules to routes
