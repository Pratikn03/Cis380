# %% [markdown]
# # Jobs and Worker Pipeline
#
# Trace async jobs from API request to worker execution.

# %% [markdown]
# ## Inputs
# - app/api/v1/jobs.py
# - app/workers
# - docker-compose.elite.yml

# %% [markdown]
# ## Outputs
# - Job lifecycle notes
# - Sample job run output

# %% [markdown]
# ## Steps
# 1. Start docker compose
# 2. Submit a job
# 3. Inspect worker logs

# %%
# TODO: call jobs endpoint
# curl -s http://localhost:8000/api/v1/jobs?limit=5
