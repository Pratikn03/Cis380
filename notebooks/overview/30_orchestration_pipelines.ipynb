# %% [markdown]
# # Orchestration Pipelines
#
# Document orchestration flows and pipeline stages.

# %% [markdown]
# ## Inputs
# - src/orchestration
# - src/pipeline
# - scripts/train_all.py

# %% [markdown]
# ## Outputs
# - Flow map
# - Stage summaries
# - Run commands

# %% [markdown]
# ## Steps
# 1. Review orchestration flows
# 2. Map pipeline stages
# 3. Capture run commands

# %%
# TODO: document orchestration pipelines
