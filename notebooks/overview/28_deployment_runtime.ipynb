# %% [markdown]
# # Deployment Runtime
#
# Document deployment configuration and service wiring.

# %% [markdown]
# ## Inputs
# - Dockerfile
# - Dockerfile.production
# - docker-compose.yml
# - compose.yaml
# - deploy
# - deploy/nginx/nginx.conf
# - deploy/prometheus/prometheus.yml

# %% [markdown]
# ## Outputs
# - Service map
# - Deployment checklist
# - Runtime configuration notes

# %% [markdown]
# ## Steps
# 1. Review Docker/compose configs
# 2. Map services and ports
# 3. Record deployment steps

# %%
# TODO: document deployment runtime
