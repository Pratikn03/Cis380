# %% [markdown]
# # Vision Local Tools
#
# Document local vision utilities (detector, embedder, analysis).

# %% [markdown]
# ## Inputs
# - app/vision_local

# %% [markdown]
# ## Outputs
# - Local vision pipeline notes
# - Model dependencies
# - Outputs schema

# %% [markdown]
# ## Steps
# 1. Review detector + embedder modules
# 2. Document analysis outputs
# 3. Record model dependency requirements

# %%
# TODO: document vision_local utilities
