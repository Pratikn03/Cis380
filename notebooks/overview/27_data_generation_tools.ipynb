# %% [markdown]
# # Data Generation Tools
#
# Document synthetic data generators and sampling utilities.

# %% [markdown]
# ## Inputs
# - app/data/fraud_generator.py
# - scripts/prepare_brand_data.py

# %% [markdown]
# ## Outputs
# - Generator notes
# - Sampling parameters
# - Generated artifacts list

# %% [markdown]
# ## Steps
# 1. Review generator inputs/outputs
# 2. Capture sampling parameters
# 3. Note output locations

# %%
# TODO: document data generation tools
