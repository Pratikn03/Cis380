# %% [markdown]
# # Fusion Engine Runtime
#
# Document fusion scoring runtime and model artifacts.

# %% [markdown]
# ## Inputs
# - app/fusion/engine.py
# - app/models/fusion
# - app/api/fusion.py
# - src/orchestration/fusion_flow.py

# %% [markdown]
# ## Outputs
# - Fusion scoring flow
# - Model artifact checklist
# - Runtime inputs/outputs

# %% [markdown]
# ## Steps
# 1. Review fusion engine logic
# 2. Capture model artifacts used
# 3. Document API request/response shape

# %%
# TODO: document fusion runtime
